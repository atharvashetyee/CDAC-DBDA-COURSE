# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import os
os.getcwd()
os.chdir(r"C:\Users\athar\Downloads")

# %%
df=pd.read_excel('CDAC_DataBook.xlsx',sheet_name='faithful')
df
# Out:
#      eruptions  waiting
# 0        3.600       79
# 1        1.800       54
# 2        3.333       74
# 3        2.283       62
# 4        4.533       85
# ..         ...      ...
# 267      4.117       81
# 268      2.150       46
# 269      4.417       90
# 270      1.817       46
# 271      4.467       74
#
# [272 rows x 2 columns]

# %%
erupt=df["eruptions"]

# %%
np.var(erupt)  #population variance #as vaiance increases value of SD and  increases
# Out:
# 1.2979388904492855

# %%
np.var(erupt,ddof=1) #sample variance
# Out:
# 1.3027283328494672

# %%
np.std(erupt) #population standard deviation
# Out:
# 1.1392712102257678

# %%
np.std(erupt,ddof=1) #sample standard deviation
# Out:
# 1.1413712511052077

# %%
#population varinace**0.5==>population S.D
1.2979388904492855**0.5
# Out:
# 1.1392712102257678

# %%
#sample variance **0.5==>sample standard deviation
1.3027283328494672**0.5
# Out:
# 1.1413712511052077

# %%
np.var(x2,ddof=1) #delta degree of freedom
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 np.var(x2,ddof=1)
#
# NameError: name 'x2' is not defined

# %%
#1.calculate the mean of all number
#2.calculate the deviation of each number from the mean

# %%
len(erupt-np.mean(erupt))
# Out:
# 272

# %%
sum(erupt-np.mean(erupt))
# Out:
# 1.4854784069484595e-13

# %%
s1=sum((erupt-np.mean(erupt))**2) #sum of squared deviation from the mean

# %%
#if all numbers are equal then variance is zero

# %%
s1/len(erupt) #population deviation-manual method
np.var(erupt)
# Out:
# 1.2979388904492855

# %%
(s1/len(erupt))**0.5
np.std(erupt)
# Out:
# 1.1392712102257678

# %%
#SD is easier than variance as it is easy to calculate for interpretation purpose
#ranking of 4 types
#SD>Variance>IQR>Range

# %%
#conservative estimate-keeping some positive error

# %%
s1/(len(erupt)-1)
# Out:
# 1.3027283328494683

# %%
np.var(erupt,ddof=1) #ddof takes random data as subset and performs var on it

# %%
s1/(len(erupt)-1)**0.5
# Out:
# 21.445614950277655

# %%
(s1/(len(erupt)-1))**0.5
# Out:
# 1.1413712511052083

# %%
np.std(erupt,ddof=1) #sample std devation
# Out:
# 1.1413712511052077

# %%
#sample means the data is subset of the entire dataset

# %%
pip install scipy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    - -------------------------------------- 1.0/38.6 MB 6.3 MB/s eta 0:00:06
#    - -------------------------------------- 1.6/38.6 MB 5.6 MB/s eta 0:00:07
#    ---- ----------------------------------- 4.2/38.6 MB 7.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.8/38.6 MB 7.3 MB/s eta 0:00:05
#    -------- ------------------------------- 8.7/38.6 MB 8.5 MB/s eta 0:00:04
#    ----------- ---------------------------- 11.0/38.6 MB 9.0 MB/s eta 0:00:04
#    -------------- ------------------------- 13.9/38.6 MB 9.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 16.8/38.6 MB 10.2 MB/s eta 0:00:03
#    --------------------- ------------------ 20.4/38.6 MB 10.9 MB/s eta 0:00:02
# ...

# %%
import scipy

# %%
from scipy import stats

# %%
scipy.stats.skew(erupt) #as value is -ve the peak is on right
# Out:
# -0.4158409529189896

# %%
scipy.stats.kurtosis(erupt) #kurtosis for getting outliers
# Out:
# -1.5006003587752426

# %%
#three types of center skewed graph
"""
normal distribution==> kurtosis=0

peak is more sharp as compared to normal
kurtosis>0

peak is less sharp as compared to normal kurtosis<0
"""
# Out:
# '\nnormal distribution==> kurtosis=0\n\npeak is more sharp as compared to normal\nkurtosis>0\n\npeak is less sharp as compared to normal kurtosis<0\n\n\n'
