# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import os
os.getcwd()
os.chdir(r"C:\Users\athar\Downloads")
import scipy
from scipy import stats

import numpy as np
from numpy import random
import pandas as pd
import scipy
from scipy import stats

import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import pylab
from pylab import legend #heading, referred as label/scale
from pylab import plot, show, title, xlabel, ylabel 

import scipy
from scipy import stats
from scipy.stats import binom,poisson
from scipy.stats import expon
from scipy.stats import norm,t
from scipy.stats import rv_discrete
import statsmodels
from statsmodels import stats
from statsmodels.stats import weightstats as ssw

# %%
df=pd.read_excel("CDAC_DataBook.xlsx",sheet_name='faithful')

# %%
df.head()
# Out:
#    eruptions  waiting
# 0      3.600       79
# 1      1.800       54
# 2      3.333       74
# 3      2.283       62
# 4      4.533       85

# %%
erupt=df.eruptions

# %%
#The population mean is atleast 3.6
#Ho mean(erupt)>=3.6
#Ha mean(erupt)<3.6

# %%
#CL=95% Los=1-0.95=0.05

# %%
#We use the 1 sample  z test to compare the mean of the sample(erupt) against the clam value which 3.6

# %%
import statsmodels
from statsmodels import stats
from statsmodels.stats import weightstats  as ssw

# %%
ssw.ztest(erupt,value=3.6,alternative='smaller')     #Error in the left side so alternative=small
# Out:
# (-1.621495827018525, 0.052455672107759366)

# %%
#Test statistics=-1.621495827018525 p-value=0.052455672107759366

# %%
#p-value (0.052) is more than the Los(0.05) so we DO NOT REJECT Ho

# %%
ssw.ztest(erupt,value=3.75,alternative='smaller')
# Out:
# (-3.7889443000505145, 7.564441324733466e-05)

# %%
np.round((7.564441324733466e-05,3))
# Out:
# array([0., 3.])

# %%
##p-value (0.0) is less than the Los(0.05) so we DO  REJECT Ho

# %%
np.mean(erupt)
# Out:
# 3.4877830882352936

# %%
ssw.ztest(erupt,value=3.602007,alternative='smaller')
# Out:
# (-1.650496287587691, 0.049420735997434614)

# %%
np.round(0.049420735997434614,3)
# Out:
# 0.049

# %%
t.cdf(-1.650496287587691,271)
# Out:
# 0.04999994796763964

# %%
np.round(0.04999994796763964,3)
# Out:
# np.float64(0.05)

# %%
z=(np.mean(erupt)-3.6)/(np.std(erupt,ddof=1)/len(erupt)**0.5)            #z=x-mu/std/sqrt(n)

# %%
z
# Out:
# -1.6214958270185256

# %%
t.ppf(0.05,271)
# Out:
# -1.650495778817526

# %%
norm.ppf(0.05)
# Out:
# -1.6448536269514729

# %%
np.mean(erupt) + 1.650495778817526 * np.std(erupt,ddof=1)/len(erupt)**0.5
# Out:
# 3.6020069647901547

# %%
ssw.ztest(erupt,value=3.7,alternative='smaller')   #Ho is reject
# Out:
# (-3.06646147570652, 0.0010830435959524984)

# %%
ssw.ztest(erupt,value=3.05,alternative='smaller')
# Out:
# (6.325815240765445, 0.9999999998740504)

# %%
np.std(erupt,ddof=1)/len(erupt)**0.5
# Out:
# 0.06920579744632573

# %%
z=(np.mean(erupt)-3.6)/(np.std(erupt,ddof=1)/len(erupt)**0.05) #refer formula to calculate z
#z=-1.644853626957788
