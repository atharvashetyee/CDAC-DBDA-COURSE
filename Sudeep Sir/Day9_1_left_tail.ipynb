# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import os
os.getcwd()
os.chdir(r"C:\Users\athar\Downloads")
import scipy
from scipy import stats

import numpy as np
from numpy import random
import pandas as pd
import scipy
from scipy import stats

import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import pylab
from pylab import legend #heading, referred as label/scale
from pylab import plot, show, title, xlabel, ylabel 

import scipy
from scipy import stats
from scipy.stats import binom,poisson
from scipy.stats import expon
from scipy.stats import norm,t
from scipy.stats import rv_discrete
import statsmodels
from statsmodels import stats
from statsmodels.stats import weightstats as ssw

# %%
pip install statsmodels
# Out:
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.6 MB 6.7 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.6 MB 4.7 MB/s eta 0:00:02
#    ------------ --------------------------- 2.9/9.6 MB 4.9 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.6 MB 4.8 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.6 MB 4.5 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.6 MB 4.4 MB/s eta 0:00:02
#    ------------------------- -------------- 6.0/9.6 MB 4.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.6 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 5.2 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [patsy]
#    -------------------- ------------------- 1/2 [statsmodels]
# ...

# %%
df=pd.read_excel("CDAC_DataBook.xlsx",sheet_name='faithful')

# %%
erupt=df.eruptions

# %%
#population mean is atleast 3.6
'''
pop mean>=3.6 H0
pop mean<3.6 Ha

Confidence level=95
LoS=0.05 /5 %
we use 1 sample z test to compare the mean of sample(erupt) against the claim value which is 3.6

1-sample T test
'''

# %%
ssw.ztest(erupt,value=3.6,alternative='smaller')  #use alternative =smaller/larger depending on the Ha(alternative)
#test statistics=-1.621495827018525
#p_value=0.052455672107759366
# Out:
# (-1.621495827018525, 0.052455672107759366)

# %%
# Out:
# (-1.621495827018525, 0.9475443278922406)

# %%
#p_value is greater than LoS we do not reject the null hypothesis

# %%
ssw.ztest(erupt,value=3.75,alternative='smaller')
#as pvalue>smaller is LoS reject the null hypothesis

np.round(7.564441324733466e-05)
# Out:
# 0.0

# %%
3.487*100/95 #ASK
# Out:
# 3.6705263157894734

# %%
ssw.ztest(erupt,value=3.602007,alternative='smaller')
# Out:
# (-1.650496287587691, 0.049420735997434614)

# %%
t.cdf(-1.650496287587691,271)
# Out:
# 0.04999994796763964

# %%
z=(np.mean(erupt)+3.6)/(np.std(erupt,ddof=1)/len(erupt)**0.05) #refer formula to calculate z
#z=-1.644853626957788

# %%
z=(np.mean(erupt)-3.6)/(np.std(erupt,ddof=1)/len(erupt)**0.5)            #z=x-mu/std/sqrt(n)
z
# Out:
# -1.6214958270185256

# %%
np.mean(erupt)
# Out:
# 3.4877830882352936

# %%
t.ppf(0.05,271) #as error is on left side, we calculate 95% Upper bound
# Out:
# -1.650495778817526

# %%
np.mean(erupt) + 1.650495778817526 * np.std(erupt,ddof=1)/len(erupt)**0.5  #same z formula
"""
here we found/creating upper bound as the value is supposed to be having a positive value added as 3.6 is higher than 3.48(mean of erupt) ,but as 
this is sample
data and difference is significantly small so it has chance variance, so inorder to calulcate that properly ,we use z formula putting value of t.ppf
and taking in postive as we want to consider positive error.
As this is left tailed val example so value is supposed to be on right side ,so we use t value we get from t.ppf
so in result we can see the mean 3.48 is given value 3.60200 so it can be considered into the "considering null hypothesis" as this pvalue >LoS

name of this approach is defenders approach,as we are looking the defending side

So if value is a bit lesser than the expected mean given, what we can do is we can calculate the upper bound for the same 
calculations we consider here upon pound because it is significantly lower than the expected one, and we also need to consider the chance variance as we are working on the sample data,
not population. 

"""
# Out:
# 3.6020069647901547

# %%
np.std(erupt,ddof=1)/len(erupt)**0.5
# Out:
# 0.06920579744632573

# %%
# Out:
# 3.6020069647901547
