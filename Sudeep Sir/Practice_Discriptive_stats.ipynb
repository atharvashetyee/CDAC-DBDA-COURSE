# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import os
os.getcwd()
os.chdir(r"C:\Users\athar\Downloads")
import scipy
from scipy import stats

import numpy as np
from numpy import random
import pandas as pd
import scipy
from scipy import stats

import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import pylab
from pylab import legend #heading, referred as label/scale
from pylab import plot, show, title, xlabel, ylabel 

import scipy
from scipy import stats
from scipy.stats import binom,poisson
from scipy.stats import expon
from scipy.stats import norm,t

# %%
"""A machine produces components with a success rate of 92%.
If you test 12 components, what is the probability that exactly 10 are non-defective?
What is the probability of minimum 10 are non-defective.
"""
binom.pmf(10,12,0.92)
1-binom.cdf(9,12,0.92)
# Out:
# 0.18348568306406207

# %%
"""
There are an average of 3 spelling mistakes everyday in a newspaper. 
What is the probability of atleast 4 mistakes.
What is the probability of max 2 spelling mistakes.

"""
poisson.sf(3,3)
poisson.cdf(2,3)
# Out:
# 0.42319008112684364

# %%
"""
The average lifespan of a device mean 6 years. 
What is the probability it survives more than 10 years? 
What is the duration below which max 10% of the devices would fail.
"""
expon.sf(10,6)
expon.ppf(0.10,6)
# Out:
# 0.01831563888873418

# %%
"""
A call center receives calls with an average inter-arrival time of 8 minutes. 
What is the probability that the next call comes within 3 minutes?
"""
expon.cdf(3,scale=8)
# Out:
# 0.3127107212090278

# %%
"""
The average height of adult males is with mean 172 cm and SD 8 cm. 
What is the probability that a randomly selected male is below 165 cm? 
What is the probability of his height being more than 175 cm

"""
norm.cdf(165,172,8)
norm.sf(175,172,8)
# Out:
# 0.3538302333272762

# %%
binom.ppf(0.5,20,0.5)
# Out:
# 10.0

# %%
#a coin is tossed 20 times tell me count how many times it lands on head

binom.cdf(10,20,0.5)
# Out:
# 0.5880985260009766

# %%
"""
pmf==>binomial and poisson
cdf==>can be used for both , used for upto a number 
sf==>greater a particular number, reduction should be in only in discrete data
ppf==>give value of x axis



"""

# %%
binom.pmf(12,20,0.5)
# Out:
# 0.12013435363769535
